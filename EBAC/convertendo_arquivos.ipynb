# %%
import pandas as pd

# %%
df_1 = pd.read_excel('produto_informatica_csv.xlsx')

# %%
df_1.to_csv('produto_informatica.csv')

# %%
df_2 = pd.read_excel('pedido_informatica_csv.xlsx')

# %%
df_2.to_csv('pedido_informatica.csv')

# %%
df_3 = pd.read_excel('cliente_informatica_csv.xlsx')

# %%
df_3.to_csv('cliente_informatica.csv')

# %%
# todos os arquivos originais foram deletados para não haver redudância
